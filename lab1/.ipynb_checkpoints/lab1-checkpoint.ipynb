# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts

# %%
df = pd.read_csv('https://raw.githubusercontent.com/OHrydko/Machine-Learning-Labs/master/lab1/MP-07-Hrydko.csv', 
                 header=0, names=['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'y'], sep=';',engine='python')
df.head()
# Out:
#         x0       x1       x2       x3  x4       x5       y
# 0  2114.97  56.1939  97.7716  3601.37  27  39.8544  17.395
# 1  1164.74  45.0019  63.9749  2026.36  22  42.8624   2.375
# 2  2192.61  55.3350  93.4638  3336.69  25  38.2677  12.987
# 3  1168.13  53.4750  63.4258  2812.04  17  39.8232   5.562
# 4  2124.26  62.2165  90.9051  2420.26  68  39.9775  14.014

# %%
# plt.figure(figsize = (16,9))
# plt.grid()
# plt.title('Незалежні зміні відносно залежної')
# for i in train.columns[:-1]:
#     plt.scatter(train[i].values, train['y'].values, marker='+', color='C'+ i[-1], label=i)
# plt.ylabel('Y')
# plt.xlabel('X')
# plt.legend(loc='best')
# plt.show()

# %%
df[df.columns[:-1]] = df[df.columns[:-1]]/df[df.columns[:-1]].max()
train = df.iloc[:200]
# визначення параметрів
system_len = len(train.columns)
alpha = 0.9

# знаходження коефіцієнтів
matrix_x = train[train.columns[:-1]].values
solve = np.dot(np.dot(np.linalg.inv(np.dot(np.transpose(matrix_x), matrix_x)), np.transpose(matrix_x)), train['y'].values)
b_0 = train[train.columns[-1]].mean() - (train[train.columns[:-1]].mean() * solve).sum()

# Оцінка статистичної значимості коефіцієнтів
# Відхилення
q_e = (train['y'] - (b_0 + train[train.columns[:-1]] * solve).sum(axis = 1))
# Оцінка дисперсії
s_2 = (q_e**2).sum()/(len(train) - system_len)
# Коефіцієнти зв'язку
K_coef = np.sqrt(np.diag(s_2 * np.linalg.inv(np.dot(np.transpose(matrix_x), matrix_x))))

t_student = round(sts.t.ppf((1 + alpha)/2, len(train) - system_len), 2)
t_calculated = (np.absolute(solve)/K_coef).round(2)
weight_coef = t_calculated > t_student

# Розрахунок коефіцієнта множиної детермінації
R = round(np.sqrt((np.dot(np.dot(np.transpose(solve), np.transpose(matrix_x)), train['y'].values) -
             len(train) * train['y'].mean())/\
    (np.dot(np.transpose(train['y'].values), train['y'].values) - len(train) * train['y'].mean())), 2)
print('Значення розподілу t = {} при параметрах alpha = {} & p = {} при'.format(t_student, alpha, len(train) - system_len))
print('b0 = {} значущий {}'.format(round(b_0, 2), False))
for i in range(len(solve)):
    print('b{} = {} значущий {} значення t роподілу = {} '
          .format(i+1, round(solve[i], 2), weight_coef[i], t_calculated[i]))
print('Коефіцієнт детермінації R = {} R^2 = {} та оцінка дисперції s^2 = {}'.format(R, round(R**2, 2), round(s_2, 2)))
# Out:
# Значення розподілу t = 1.65 при параметрах alpha = 0.9 & p = 193 при
# b0 = 0.04 значущий False
# b1 = 20.9 значущий True значення t роподілу = 3.19
# b2 = -38.32 значущий True значення t роподілу = 5.58
# b3 = 19.95 значущий True значення t роподілу = 1.73
# b4 = -12.49 значущий True значення t роподілу = 1.75
# b5 = 9.82 значущий True значення t роподілу = 3.87
# b6 = 8.9 значущий True значення t роподілу = 7.36
# Коефіцієнт детермінації R = 0.84 R^2 = 0.71 та оцінка дисперції s^2 = 26.46

# %%
def q_func(w0, wi):
    return ((1/len(X_matrix)) * ((w0 + train[train.columns[:-1]] * wi).sum(axis = 1) - train['y'])**2).mean()
# Градієнт функції
def gradient(w0, wi):
    w_0 = (2/len(X_matrix)) * ((w0 + train[train.columns[:-1]] * wi).sum(axis = 1) - train['y']).sum()
    w_i = list((2/len(X_matrix)) * \
    np.dot(np.transpose(X_matrix), ((w0 + train[train.columns[:-1]] * wi).sum(axis = 1) - train['y'])))
    w_i.append(w_0)
    return w_i

def answer(w_arg):
    lam = 1
    return w_arg - lam * np.array(gradient(w_arg[-1], w_arg[:-1])) / (w_arg**2).sum()

# %%
w = [np.random.uniform(0, 1, size=dim_system)]
epsilon = 0.0001
error = []
k = [0]
while True:
    w.append(answer(w[-1]))
    error.append(np.absolute(q_func(w[-1][-1], w[-1][:-1]) - q_func(w[-2][-1], w[-2][:-1])))
    print('Крок = {} Значення помилки = {} \n Вектор значень аргументів {}'.format(k[-1], error[-1], w[-1]))
    if error[-1] < epsilon:
        break
    k.append(k[-1] + 1) 
coef_regretion = w[-1]
print('-------------Результати---------------------')
print('Кроків = {} Значення помилки = {} \n Вектор значень аргументів {}'.format(k[-1], error[-1], coef_regretion))
# Out:
# Крок = 0 Значення помилки = 3.7855767360590886
#  Вектор значень аргументів [2.23640373 1.78180472 1.63675562 1.31877721 1.70195595 4.02297851
#  4.92486191]
# Крок = 1 Значення помилки = 1.69856516248996
#  Вектор значень аргументів [1.87582114 1.43592377 1.26911018 1.04664784 1.46048612 3.2970862
#  3.93266724]
# Крок = 2 Значення помилки = 1.3360912379059924
#  Вектор значень аргументів [1.46659185 1.03899036 0.84980559 0.73649045 1.1863006  2.47263338
#  2.80386914]
# Крок = 3 Значення помилки = 0.7485999515184872
#  Вектор значень аргументів [1.00324996 0.57719341 0.36924823 0.38160972 0.87547033 1.53735761
#  1.51803799]
# Крок = 4 Значення помилки = 0.00024683568386385524
#  Вектор значень аргументів [ 0.6395113   0.14982121 -0.03843605  0.08354245  0.62943533  0.79343697
#   0.46765678]
# Крок = 5 Значення помилки = 3.673890325848857
#  Вектор значень аргументів [2.34079712 1.35229391 1.49461334 1.23782152 1.75568101 4.14858576
#  4.87214852]
# Крок = 6 Значення помилки = 1.6719268511822394
#  Вектор значень аргументів [1.98045487 1.00662347 1.12719662 0.96570274 1.51445269 3.42188369
#  3.87929503]
# Крок = 7 Значення помилки = 1.300720495794626
#  Вектор значень аргументів [1.57349135 0.61176136 0.71014382 0.6569748  1.24190398 2.60002034
#  2.75468496]
# Крок = 8 Значення помилки = 0.7094711976818305
#  Вектор значень аргументів [1.12022078 0.15942093 0.23974019 0.30917666 0.93803501 1.68141217
#  1.49281444]
# Крок = 9 Значення помилки = 0.01024373741494261
#  Вектор значень аргументів [ 0.79452147 -0.22767333 -0.12743115  0.03974778  0.71817671  1.00518571
#   0.53992568]
# Крок = 10 Значення помилки = 1.0419036513287268
#  Вектор значень аргументів [1.79710336 0.45445087 0.76343118 0.70855363 1.38269068 2.95139294
#  3.09139993]
# Крок = 11 Значення помилки = 0.8931389137380352
#  Вектор значень аргументів [1.36618887 0.02955328 0.31863268 0.37930474 1.09402414 2.07773034
#  1.89386791]
# Крок = 12 Значення помилки = 0.18776092736901734
#  Вектор значень аргументів [ 0.96862873 -0.39459485 -0.10684687  0.06516479  0.82702723  1.26123821
#   0.7630114 ]
# Крок = 13 Значення помилки = 0.07409081217104352
#  Вектор значень аргументів [ 1.31756214 -0.22708186  0.1703228   0.2746723   1.05710837  1.91046199
#   1.58898593]
# Крок = 14 Значення помилки = 0.06274221408256658
#  Вектор значень аргументів [ 1.00409553 -0.58509578 -0.17625358  0.01907877  0.84619399  1.25678877
#   0.67600165]
# Крок = 15 Значення помилки = 0.1216946120656976
#  Вектор значень аргументів [ 1.44848955 -0.32187564  0.20017606  0.30136282  1.14048503  2.09489916
#   1.76332484]
# Крок = 16 Значення помилки = 0.13689235036853392
#  Вектор значень аргументів [ 1.10915521 -0.69184919 -0.16673707  0.03019225  0.91258217  1.39176323
#   0.78798386]
# Крок = 17 Значення помилки = 0.021586366204078417
#  Вектор значень аргументів [ 1.35493998 -0.58342124  0.02397348  0.17365497  1.07477711  1.83810063
#   1.35411789]
# Крок = 18 Значення помилки = 0.01905271029258976
#  Вектор значень аргументів [ 1.16092445 -0.83474051 -0.20452924  0.00521068  0.94380827  1.41887322
#   0.75995238]
# Крок = 19 Значення помилки = 0.018075756742651383
#  Вектор значень аргументів [ 1.41324475 -0.71032144 -0.00258938  0.15646541  1.11064836  1.87941136
#   1.34980708]
# Крок = 20 Значення помилки = 0.02240659665402933
#  Вектор значень аргументів [ 1.23302704e+00 -9.44338118e-01 -2.15113811e-01 -3.99890016e-04
#   9.89032421e-01  1.48817161e+00  7.95782518e-01]
# Крок = 21 Значення помилки = 0.005069028796697933
#  Вектор значень аргументів [ 1.42686395 -0.86127847 -0.06587565  0.11130535  1.11705098  1.83447801
#   1.23534346]
# Крок = 22 Значення помилки = 0.010005911889142155
#  Вектор значень аргументів [ 1.30893565e+00 -1.03860427e+00 -2.16329799e-01  3.11867653e-04
#   1.03710192e+00  1.56651566e+00  8.49113175e-01]
# Крок = 23 Значення помилки = 0.00027508279051596807
#  Вектор значень аргументів [ 1.44154036 -1.00104564 -0.1233016   0.06998217  1.12440384  1.79314112
#   1.13017737]
# Крок = 24 Значення помилки = 0.0033164174566953086
#  Вектор значень аргументів [ 1.3835828  -1.12308595 -0.21366359  0.0034019   1.08457424  1.64426477
#   0.9062366 ]
# Крок = 25 Значення помилки = 0.0008313326756642925
#  Вектор значень аргументів [ 1.4645795  -1.12415473 -0.16814023  0.03758596  1.13754143  1.77017419
#   1.05373781]
# Крок = 26 Значення помилки = 0.0008475984645608392
#  Вектор значень аргументів [ 1.45097751 -1.20392279 -0.2134063   0.00430361  1.12740542  1.70985513
#   0.9509795 ]
# Крок = 27 Значення помилки = 0.00035475546101859656
#  Вектор значень аргументів [ 1.49773399 -1.22972991 -0.19898176  0.01523783  1.1576029   1.76929108
#   1.01064694]
# Крок = 28 Значення помилки = 0.00023115758072650427
#  Вектор значень аргументів [ 1.50812245e+00 -1.28479847e+00 -2.18992918e-01  5.51576002e-04
#   1.16355685e+00  1.75742880e+00  9.74882055e-01]
# Крок = 29 Значення помилки = 0.00015873253630757644
#  Вектор значень аргументів [ 1.53792249e+00 -1.32122275e+00 -2.19200118e-01  4.95678187e-04
#   1.18250357e+00  1.78445821e+00  9.92357880e-01]
# Крок = 30 Значення помилки = 0.00013378703329230968
#  Вектор значень аргументів [ 1.55711217 -1.36502985 -0.22891069 -0.00666656  1.19439562  1.7910366
#   0.98290165]
# Крок = 31 Значення помилки = 0.00012461893899326504
#  Вектор значень аргументів [ 1.58057641 -1.40346023 -0.23366199 -0.01020076  1.2091687   1.80656955
#   0.98617665]
# Крок = 32 Значення помилки = 0.00011939857021200928
#  Вектор значень аргументів [ 1.60151914 -1.44250313 -0.24013416 -0.01505726  1.22228254  1.81760435
#   0.98396766]
# Крок = 33 Значення помилки = 0.00011578989948468621
#  Вектор значень аргументів [ 1.62283331 -1.47974104 -0.24554562 -0.01916859  1.23566672  1.82984571
#   0.98394287]
# Крок = 34 Значення помилки = 0.00011246729539010625
#  Вектор значень аргументів [ 1.64342817 -1.51620722 -0.25100238 -0.02335126  1.24859097  1.84112048
#   0.98312991]
# Крок = 35 Значення помилки = 0.00010941800020719539
#  Вектор значень аргументів [ 1.66371782 -1.5516191  -0.25613612 -0.02732872  1.26133012  1.85223271
#   0.98258318]
# Крок = 36 Значення помилки = 0.0001065367076981405
#  Вектор значень аргументів [ 1.68359305 -1.58614347 -0.26108735 -0.03120217  1.27380971  1.86295167
#   0.98196126]
# Крок = 37 Значення помилки = 0.00010382296984925987
#  Вектор значень аргументів [ 1.70310873 -1.61979829 -0.26583331 -0.03495201  1.28606505  1.8733719
#   0.98136504]
# Крок = 38 Значення помилки = 0.0001012575600369825
#  Вектор значень аргументів [ 1.72227091 -1.65263901 -0.27039666 -0.03859263  1.29809894  1.88349182
#   0.98076773]
# Крок = 39 Значення помилки = 9.882964273252859e-05
#  Вектор значень аргументів [ 1.74109704 -1.68470646 -0.27478668 -0.04212872  1.30992194  1.89333303
#   0.98017592]
# -------------Результати---------------------
# Кроків = 39 Значення помилки = 9.882964273252859e-05
#  Вектор значень аргументів [ 1.74109704 -1.68470646 -0.27478668 -0.04212872  1.30992194  1.89333303
#   0.98017592]

# %%
# plt.figure(figsize = (16,9))
# plt.grid()
# plt.title('Значення функції помилки')
# plt.plot(k, error_func, color='r', label='error')
# plt.ylabel('value')
# plt.xlabel('iteration')
# plt.legend(loc='best')
# plt.show()

# %%
test = df.iloc[200:]
error_2_lsm = ((test['y'] - (b_0_matrix + test[test.columns[:-1]] * martix_solve).sum(axis = 1))**2).mean()
error_2_grad = ((test['y'] - (coef_regretion[-1] + test[test.columns[:-1]] * coef_regretion[:-1]).sum(axis = 1))**2).mean()
print('Похибка МНК       = {} \nПохибка градієнта = {}'.format(error_2_lsm, error_2_grad))
# Out:
# Похибка МНК       = 27.247791457115863
# Похибка градієнта = 38.436547248402235
